# %%
import pandas as pd  # pandas library import
import mysql.connector
import os
import matplotlib.pyplot as plt

# %%
conn = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "Brijesh@296148",
    database = "Ecommerce"
)

cursor = conn.cursor()

# %% [markdown]
# # 1. List all unique cities where customers are located.

# %%
query = """
        select distinct(customer_city) from customers;
        """
cursor.execute(query)

data = cursor.fetchall()

# %%
data
# Out:
# [('franca',),
#  ('sao bernardo do campo',),
#  ('sao paulo',),
#  ('mogi das cruzes',),
#  ('campinas',),
#  ('jaragua do sul',),
#  ('timoteo',),
#  ('curitiba',),
#  ('belo horizonte',),
#  ('montes claros',),
#  ('rio de janeiro',),
#  ('lencois paulista',),
#  ('caxias do sul',),
#  ('piracicaba',),
#  ('guarulhos',),
#  ('pacaja',),
#  ('florianopolis',),
#  ('aparecida de goiania',),
#  ('santo andre',),
#  ('goiania',),
#  ('cachoeiro de itapemirim',),
#  ('sao jose dos campos',),
#  ('sao roque',),
#  ('camacari',),
#  ('resende',),
#  ('sumare',),
#  ('novo hamburgo',),
#  ('sao luis',),
#  ('sao jose',),
#  ('santa barbara',),
#  ('ribeirao preto',),
#  ('ituiutaba',),
#  ('taquarituba',),
#  ('sao jose dos pinhais',),
#  ('barrinha',),
#  ('parati',),
#  ('dourados',),
#  ('trindade',),
#  ('cascavel',),
#  ('fortaleza',),
#  ('brasilia',),
#  ('pelotas',),
#  ('porto alegre',),
#  ('salto',),
#  ('jundiai',),
#  ('cacapava',),
#  ('sao vicente',),
#  ('uberlandia',),
# ...

# %% [markdown]
# #  2. Count the number of orders placed in 2017.

# %%
query = """
            select count(order_id) as ID from orders where order_purchase_timestamp = 2017;
        """
cursor.execute(query)
data = cursor.fetchall()
data
# Out:
# [(45101,)]

# %% [markdown]
# # 3. Find the total sales per category.

# %%
query = """
            select product_category, round(sum(payments.payment_value), 2) from products
            join order_items on order_items.product_id  = products.product_id
            join payments on payments.order_id = order_items.order_id
            group by products.product_category;
        """
cursor.execute(query)
data = cursor.fetchall()
df = pd.DataFrame(data,columns = ["Category", "Sales"])
df
# Out:
#                        Category       Sales
# 0                     perfumery   506738.66
# 1          Furniture Decoration  1430176.39
# 2                     telephony   486882.05
# 3                bed table bath  1712553.67
# 4                    automotive   852294.33
# ..                          ...         ...
# 69               cds music dvds     1199.43
# 70                   La Cuisine     2913.53
# 71  Fashion Children's Clothing      785.67
# 72                     PC Gamer     2174.43
# 73       insurance and services      324.51
#
# [74 rows x 2 columns]

# %% [markdown]
# ## 4. Calculate the percentage of orders that were paid in installments.

# %%
query = """
            
        """
cursor.execute(query)
data = cursor.fetchall()
data

# %% [markdown]
# ## 5. Count the number of customers from each state.

# %%
query = """
            select customer_state, count(customer_id) from customers group by customers.customer_state;
        """
cursor.execute(query)
data = cursor.fetchall()
df = pd.DataFrame(data, columns = ["State", "Total Customers"])
df = df.sort_values(by = "Total Customers", ascending = False)
plt.xticks(rotation = 90)
plt.bar(df["State"], df["Total Customers"])
plt.show()

# %% [markdown]
# ## 6. Calculate the number of orders per month in 2018.

# %%
query = """
            select monthname(order_purchase_timestamp) Months, count(order_id) from orders where year(order_purchase_timestamp) = 2018 group by Months;
        """
cursor.execute(query)
data = cursor.fetchall()
df = pd.DataFrame(data, columns=["Months", "Number of Orders"])
plt.xticks(rotation = 90)
plt.bar(df["Months"], df["Number of Orders"])
plt.show()

# %% [markdown]
# ## 7. Find the average number of products per order, grouped by customer city.

# %%
query = """
            
        """
cursor.execute(query)
data = cursor.fetchall()
data
